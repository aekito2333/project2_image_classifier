# %% [markdown]
# # Your First AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) from Oxford of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load the image dataset and create a pipeline.
# * Build and Train an image classifier on this dataset.
# * Use your trained model to perform inference on flower images.
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.

# %% [markdown]
# ## Import Resources

# %%
# The new version of dataset is only available in the tfds-nightly package.
# %pip install absl-py
# %pip --no-cache-dir install tensorflow-datasets --user
# DON'T MISS TO RESTART THE KERNEL
# Out:
# Requirement already satisfied: absl-py in c:\users\user\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from absl-py) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow-datasets in c:\users\user\appdata\roaming\python\python37\site-packages (4.2.0)
# Requirement already satisfied: protobuf>=3.12.2 in c:\users\user\appdata\roaming\python\python37\site-packages (from tensorflow-datasets) (3.14.0)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from tensorflow-datasets) (4.32.1)
# Requirement already satisfied: future in c:\users\user\anaconda3\lib\site-packages (from tensorflow-datasets) (0.17.1)
# Requirement already satisfied: importlib-resources in c:\users\user\appdata\roaming\python\python37\site-packages (from tensorflow-datasets) (5.1.0)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from tensorflow-datasets) (1.19.5)
# Requirement already satisfied: termcolor in c:\users\user\anaconda3\lib\site-packages (from tensorflow-datasets) (1.1.0)
# Requirement already satisfied: attrs>=18.1.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-datasets) (19.1.0)
# Requirement already satisfied: tensorflow-metadata in c:\users\user\appdata\roaming\python\python37\site-packages (from tensorflow-datasets) (0.27.0)
# Requirement already satisfied: absl-py in c:\users\user\anaconda3\lib\site-packages (from tensorflow-datasets) (0.10.0)
# Requirement already satisfied: promise in c:\users\user\appdata\roaming\python\python37\site-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-datasets) (2.22.0)
# Requirement already satisfied: typing-extensions in c:\users\user\anaconda3\lib\site-packages (from tensorflow-datasets) (3.7.4)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from tensorflow-datasets) (1.15.0)
# Requirement already satisfied: dill in c:\users\user\appdata\roaming\python\python37\site-packages (from tensorflow-datasets) (0.3.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow-datasets) (3.0.4)
# Requirement already satisfied: zipp>=0.4 in c:\users\user\anaconda3\lib\site-packages (from importlib-resources->tensorflow-datasets) (0.5.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in c:\users\user\appdata\roaming\python\python37\site-packages (from tensorflow-metadata->tensorflow-datasets) (1.52.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import TensorFlow 
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_hub as hub
tfds.disable_progress_bar()

# Check tf version updated
print('Using:')
print('\t\u2022 TensorFlow version:', tf.__version__)
print('\t\u2022 tf.keras version:', tf.keras.__version__)
print('\t\u2022 Running on GPU' if tf.test.is_gpu_available() else '\t\u2022 GPU device not found. Running on CPU')
# Out:
# Using:
# 	• TensorFlow version: 2.4.1
# 	• tf.keras version: 2.4.0
# WARNING:tensorflow:From <ipython-input-2-b60887f1ee47>:11: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 	• GPU device not found. Running on CPU

# %%
# TODO: Make all other necessary imports.
import warnings
warnings.filterwarnings('ignore')

import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the Dataset
#
# Here you'll use `tensorflow_datasets` to load the [Oxford Flowers 102 dataset](https://www.tensorflow.org/datasets/catalog/oxford_flowers102). This dataset has 3 splits: `'train'`, `'test'`, and `'validation'`.  You'll also need to make sure the training data is normalized and resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet, but you'll still need to normalize and resize the images to the appropriate size.

# %%
# Download data to default local directory "~/tensorflow_datasets"
# !python -m tensorflow_datasets.scripts.download_and_prepare --register_checksums=True --datasets=oxford_flowers102
# %pip install tfds-nightly

# TODO: Load the dataset with TensorFlow Datasets. Hint: use tfds.load()
dataset, dataset_info = tfds.load('oxford_flowers102', as_supervised = True, with_info = True)
# Out:
# 2021-02-13 10:52:21.002125: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-02-13 10:52:21.002387: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# usage: download_and_prepare.py build [-h] [--helpfull]
#                                      [--module_import MODULE_IMPORT]
#                                      [--builder_config_id BUILDER_CONFIG_ID]
#                                      [--datasets DATASETS_KEYWORD [DATASETS_KEYWORD ...]]
#                                      [--overwrite]
#                                      [--max_examples_per_split [MAX_EXAMPLES_PER_SPLIT]]
#                                      [--data_dir DATA_DIR]
#                                      [--download_dir DOWNLOAD_DIR]
#                                      [--extract_dir EXTRACT_DIR]
#                                      [--manual_dir MANUAL_DIR]
#                                      [--add_name_to_manual_dir]
#                                      [--config CONFIG]
#                                      [--config_idx CONFIG_IDX]
#                                      [--imports IMPORTS]
#                                      [--register_checksums]
#                                      [--force_checksums_validation]
#                                      [--beam_pipeline_options BEAM_PIPELINE_OPTIONS]
#                                      [--exclude_datasets EXCLUDE_DATASETS]
#                                      [--experimental_latest_version]
#                                      [datasets [datasets ...]]
# download_and_prepare.py build: error: argument --register_checksums: ignored explicit argument 'True'
# Requirement already satisfied: tfds-nightly in c:\users\user\anaconda3\lib\site-packages (4.2.0.dev202101290106)
# Requirement already satisfied: future in c:\users\user\anaconda3\lib\site-packages (from tfds-nightly) (0.17.1)
# Requirement already satisfied: importlib-resources in c:\users\user\appdata\roaming\python\python37\site-packages (from tfds-nightly) (5.1.0)
# Requirement already satisfied: dill in c:\users\user\appdata\roaming\python\python37\site-packages (from tfds-nightly) (0.3.0)
# Requirement already satisfied: termcolor in c:\users\user\anaconda3\lib\site-packages (from tfds-nightly) (1.1.0)
# Requirement already satisfied: protobuf>=3.12.2 in c:\users\user\appdata\roaming\python\python37\site-packages (from tfds-nightly) (3.14.0)
# Requirement already satisfied: attrs>=18.1.0 in c:\users\user\anaconda3\lib\site-packages (from tfds-nightly) (19.1.0)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from tfds-nightly) (1.15.0)
# Requirement already satisfied: absl-py in c:\users\user\anaconda3\lib\site-packages (from tfds-nightly) (0.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\user\anaconda3\lib\site-packages (from tfds-nightly) (2.22.0)
# Requirement already satisfied: tensorflow-metadata in c:\users\user\appdata\roaming\python\python37\site-packages (from tfds-nightly) (0.27.0)
# Requirement already satisfied: promise in c:\users\user\appdata\roaming\python\python37\site-packages (from tfds-nightly) (2.3)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from tfds-nightly) (1.19.5)
# Requirement already satisfied: typing-extensions in c:\users\user\anaconda3\lib\site-packages (from tfds-nightly) (3.7.4)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from tfds-nightly) (4.32.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->tfds-nightly) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->tfds-nightly) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->tfds-nightly) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->tfds-nightly) (2019.6.16)
# Requirement already satisfied: zipp>=0.4 in c:\users\user\anaconda3\lib\site-packages (from importlib-resources->tfds-nightly) (0.5.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in c:\users\user\appdata\roaming\python\python37\site-packages (from tensorflow-metadata->tfds-nightly) (1.52.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# TODO: Create a training set, a validation set and a test set.
training_set, validation_set, test_set = dataset['train'], dataset['validation'], dataset['test']

# %% [markdown]
# ## Explore the Dataset

# %%
# Print the number of elements in dataset
#print('dataset has {:,} elements '.format(len(dataset)))

# TODO: Get the number of examples in each set from the dataset info.
print('train dataset size:', dataset_info.splits['train'].num_examples)
print('validation dataset size:', dataset_info.splits['validation'].num_examples)
print('test dataset size:', dataset_info.splits['test'].num_examples)

# TODO: Get the number of classes in the dataset from the dataset info.
print('number of classes:', dataset_info.features['label'].num_classes)
# Out:
# train dataset size: 1020
# validation dataset size: 1020
# test dataset size: 6149
# number of classes: 102

# %%
# Display dataset_info
#dataset_info

# %%
dataset_info.features['label']
# Out:
# ClassLabel(shape=(), dtype=tf.int64, num_classes=102)

# %%
# TODO: Print the shape and corresponding label of 3 images in the training set.
for image, label in training_set.take(3):
    shape = image.shape
    label = label.numpy()
    print('The shape of this image is:', shape)
    print('The label of this image is:', label)
# Out:
# The shape of this image is: (500, 667, 3)
# The label of this image is: 72
# The shape of this image is: (500, 666, 3)
# The label of this image is: 84
# The shape of this image is: (670, 500, 3)
# The label of this image is: 70

# %%
# TODO: Plot 1 image from the training set. 
for image, label in training_set.take(1):
    image = image.numpy().squeeze()
    label = label.numpy()

plt.imshow(image, cmap= plt.cm.binary)
# Set the title of the plot to the corresponding image label. 
plt.title(label)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Label Mapping
#
# You'll also need to load in a mapping from label to category name. You can find this in the file `label_map.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/3.7/library/json.html). This will give you a dictionary mapping the integer coded labels to the actual names of the flowers.

# %%
import json
with open('C:\\Users\\user\\Downloads\\label_map.json', 'r') as f:
    class_names = json.load(f)
#print(class_names['72'])

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding class name. 
for image, label in training_set.take(1):
    image = image.numpy().squeeze()
    label = label.numpy()
#     print(type(label))
#     print(label)

plt.imshow(image, cmap= plt.cm.binary)
plt.title(class_names[str(label)])
plt.colorbar()
plt.show()

# %% [markdown]
# ## Create Pipeline

# %%
# TODO: Create a pipeline for each set.
num_training_examples = dataset_info.splits['train'].num_examples

batch_size = 32
image_size = 224

def format_image(image, label):
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, (image_size, image_size))
    image /= 255
    return image, label


training_batches = training_set.shuffle(num_training_examples//4).map(format_image).batch(batch_size).prefetch(1)
validation_batches = validation_set.map(format_image).batch(batch_size).prefetch(1)
testing_batches = test_set.map(format_image).batch(batch_size).prefetch(1)

# %%
print(num_training_examples)
# Out:
# 1020

# %% [markdown]
# # Build and Train the Classifier
#
# Now that the data is ready, it's time to build and train the classifier. You should use the MobileNet pre-trained model from TensorFlow Hub to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students!
#
# Refer to the rubric for guidance on successfully completing this section. Things you'll need to do:
#
# * Load the MobileNet pre-trained network from TensorFlow Hub.
# * Define a new, untrained feed-forward network as a classifier.
# * Train the classifier.
# * Plot the loss and accuracy values achieved during training for the training and validation set.
# * Save your trained model as a Keras model.
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right.
#
# **Note for Workspace users:** One important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module. Also, If your model is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# Import MobileNet pre-trained network from TensorFlow
URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
feature_extractor = hub.KerasLayer(URL, input_shape=(image_size, image_size,3))

# Freeze parameters of mobelnet
feature_extractor.trainable = False

model = tf.keras.models.Sequential([
            feature_extractor,
            tf.keras.layers.Dense(102, activation = 'softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 102)               130662
# =================================================================
# Total params: 2,388,646
# Trainable params: 130,662
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
# print('Is there a GPU Available:', tf.test.is_gpu_available())

# %%
# TODO: Build and train your network.
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

EPOCHS = 5

history = model.fit(training_batches,
                    epochs=EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/5
# 32/32 [==============================] - ETA: 3:14 - loss: 4.8829 - accuracy: 0.0000e+ - ETA: 33s - loss: 4.7588 - accuracy: 0.0234     - ETA: 33s - loss: 4.7336 - accuracy: 0.026 - ETA: 31s - loss: 4.7438 - accuracy: 0.025 - ETA: 30s - loss: 4.7650 - accuracy: 0.025 - ETA: 29s - loss: 4.7878 - accuracy: 0.025 - ETA: 28s - loss: 4.8084 - accuracy: 0.025 - ETA: 27s - loss: 4.8261 - accuracy: 0.024 - ETA: 26s - loss: 4.8472 - accuracy: 0.024 - ETA: 25s - loss: 4.8637 - accuracy: 0.024 - ETA: 24s - loss: 4.8769 - accuracy: 0.024 - ETA: 23s - loss: 4.8799 - accuracy: 0.025 - ETA: 22s - loss: 4.8829 - accuracy: 0.026 - ETA: 21s - loss: 4.8839 - accuracy: 0.028 - ETA: 20s - loss: 4.8843 - accuracy: 0.029 - ETA: 19s - loss: 4.8830 - accuracy: 0.030 - ETA: 18s - loss: 4.8810 - accuracy: 0.032 - ETA: 17s - loss: 4.8768 - accuracy: 0.033 - ETA: 16s - loss: 4.8711 - accuracy: 0.034 - ETA: 15s - loss: 4.8647 - accuracy: 0.036 - ETA: 14s - loss: 4.8570 - accuracy: 0.037 - ETA: 13s - loss: 4.8486 - accuracy: 0.039 - ETA: 11s - loss: 4.8397 - accuracy: 0.041 - ETA: 10s - loss: 4.8296 - accuracy: 0.042 - ETA: 9s - loss: 4.8190 - accuracy: 0.044 - ETA: 7s - loss: 4.8081 - accuracy: 0.04 - ETA: 6s - loss: 4.7966 - accuracy: 0.04 - ETA: 5s - loss: 4.7848 - accuracy: 0.04 - ETA: 3s - loss: 4.7727 - accuracy: 0.05 - ETA: 2s - loss: 4.7608 - accuracy: 0.05 - ETA: 1s - loss: 4.7487 - accuracy: 0.05 - ETA: 0s - loss: 4.7366 - accuracy: 0.05 - 84s 3s/step - loss: 4.7251 - accuracy: 0.0577 - val_loss: 3.1666 - val_accuracy: 0.3559
# Epoch 2/5
# 32/32 [==============================] - ETA: 54s - loss: 2.6472 - accuracy: 0.656 - ETA: 35s - loss: 2.6055 - accuracy: 0.648 - ETA: 35s - loss: 2.5648 - accuracy: 0.654 - ETA: 37s - loss: 2.5246 - accuracy: 0.662 - ETA: 36s - loss: 2.5013 - accuracy: 0.667 - ETA: 36s - loss: 2.4833 - accuracy: 0.669 - ETA: 36s - loss: 2.4731 - accuracy: 0.668 - ETA: 36s - loss: 2.4679 - accuracy: 0.666 - ETA: 35s - loss: 2.4593 - accuracy: 0.666 - ETA: 34s - loss: 2.4536 - accuracy: 0.666 - ETA: 32s - loss: 2.4479 - accuracy: 0.665 - ETA: 31s - loss: 2.4416 - accuracy: 0.664 - ETA: 30s - loss: 2.4363 - accuracy: 0.663 - ETA: 28s - loss: 2.4303 - accuracy: 0.662 - ETA: 26s - loss: 2.4236 - accuracy: 0.661 - ETA: 24s - loss: 2.4161 - accuracy: 0.661 - ETA: 22s - loss: 2.4089 - accuracy: 0.660 - ETA: 20s - loss: 2.4024 - accuracy: 0.660 - ETA: 18s - loss: 2.3956 - accuracy: 0.660 - ETA: 17s - loss: 2.3894 - accuracy: 0.660 - ETA: 15s - loss: 2.3829 - accuracy: 0.660 - ETA: 13s - loss: 2.3764 - accuracy: 0.660 - ETA: 12s - loss: 2.3701 - accuracy: 0.661 - ETA: 11s - loss: 2.3643 - accuracy: 0.661 - ETA: 9s - loss: 2.3593 - accuracy: 0.660 - ETA: 8s - loss: 2.3539 - accuracy: 0.66 - ETA: 6s - loss: 2.3485 - accuracy: 0.66 - ETA: 5s - loss: 2.3424 - accuracy: 0.66 - ETA: 4s - loss: 2.3362 - accuracy: 0.66 - ETA: 2s - loss: 2.3299 - accuracy: 0.66 - ETA: 1s - loss: 2.3237 - accuracy: 0.66 - ETA: 0s - loss: 2.3177 - accuracy: 0.66 - 85s 3s/step - loss: 2.3121 - accuracy: 0.6619 - val_loss: 2.0262 - val_accuracy: 0.6559
# Epoch 3/5
# 32/32 [==============================] - ETA: 47s - loss: 1.2793 - accuracy: 0.843 - ETA: 28s - loss: 1.3235 - accuracy: 0.851 - ETA: 26s - loss: 1.3319 - accuracy: 0.862 - ETA: 25s - loss: 1.3325 - accuracy: 0.867 - ETA: 23s - loss: 1.3187 - accuracy: 0.874 - ETA: 23s - loss: 1.3107 - accuracy: 0.879 - ETA: 23s - loss: 1.3011 - accuracy: 0.884 - ETA: 22s - loss: 1.2935 - accuracy: 0.888 - ETA: 22s - loss: 1.2846 - accuracy: 0.890 - ETA: 22s - loss: 1.2779 - accuracy: 0.891 - ETA: 22s - loss: 1.2703 - accuracy: 0.892 - ETA: 22s - loss: 1.2662 - accuracy: 0.892 - ETA: 21s - loss: 1.2614 - accuracy: 0.892 - ETA: 21s - loss: 1.2570 - accuracy: 0.892 - ETA: 20s - loss: 1.2524 - accuracy: 0.892 - ETA: 19s - loss: 1.2486 - accuracy: 0.892 - ETA: 18s - loss: 1.2462 - accuracy: 0.892 - ETA: 17s - loss: 1.2445 - accuracy: 0.891 - ETA: 16s - loss: 1.2424 - accuracy: 0.891 - ETA: 15s - loss: 1.2404 - accuracy: 0.890 - ETA: 13s - loss: 1.2382 - accuracy: 0.890 - ETA: 12s - loss: 1.2357 - accuracy: 0.890 - ETA: 11s - loss: 1.2333 - accuracy: 0.890 - ETA: 10s - loss: 1.2313 - accuracy: 0.890 - ETA: 8s - loss: 1.2290 - accuracy: 0.890 - ETA: 7s - loss: 1.2266 - accuracy: 0.89 - ETA: 6s - loss: 1.2241 - accuracy: 0.89 - ETA: 5s - loss: 1.2214 - accuracy: 0.89 - ETA: 3s - loss: 1.2188 - accuracy: 0.89 - ETA: 2s - loss: 1.2160 - accuracy: 0.89 - ETA: 1s - loss: 1.2134 - accuracy: 0.89 - ETA: 0s - loss: 1.2107 - accuracy: 0.89 - 83s 3s/step - loss: 1.2082 - accuracy: 0.8918 - val_loss: 1.5426 - val_accuracy: 0.7167
# Epoch 4/5
# 32/32 [==============================] - ETA: 57s - loss: 0.6232 - accuracy: 0.937 - ETA: 39s - loss: 0.6829 - accuracy: 0.937 - ETA: 38s - loss: 0.6715 - accuracy: 0.944 - ETA: 36s - loss: 0.6713 - accuracy: 0.948 - ETA: 34s - loss: 0.6749 - accuracy: 0.950 - ETA: 34s - loss: 0.6836 - accuracy: 0.951 - ETA: 33s - loss: 0.6897 - accuracy: 0.952 - ETA: 31s - loss: 0.6958 - accuracy: 0.953 - ETA: 30s - loss: 0.6985 - accuracy: 0.954 - ETA: 29s - loss: 0.6991 - accuracy: 0.955 - ETA: 28s - loss: 0.7014 - accuracy: 0.955 - ETA: 27s - loss: 0.7017 - accuracy: 0.956 - ETA: 26s - loss: 0.7022 - accuracy: 0.956 - ETA: 24s - loss: 0.7026 - accuracy: 0.956 - ETA: 23s - loss: 0.7033 - accuracy: 0.956 - ETA: 21s - loss: 0.7030 - accuracy: 0.956 - ETA: 20s - loss: 0.7022 - accuracy: 0.957 - ETA: 18s - loss: 0.7014 - accuracy: 0.957 - ETA: 17s - loss: 0.7012 - accuracy: 0.957 - ETA: 16s - loss: 0.7008 - accuracy: 0.956 - ETA: 15s - loss: 0.7003 - accuracy: 0.956 - ETA: 13s - loss: 0.6998 - accuracy: 0.956 - ETA: 12s - loss: 0.6995 - accuracy: 0.956 - ETA: 10s - loss: 0.6990 - accuracy: 0.956 - ETA: 9s - loss: 0.6984 - accuracy: 0.956 - ETA: 7s - loss: 0.6977 - accuracy: 0.95 - ETA: 6s - loss: 0.6969 - accuracy: 0.95 - ETA: 5s - loss: 0.6962 - accuracy: 0.95 - ETA: 3s - loss: 0.6955 - accuracy: 0.95 - ETA: 2s - loss: 0.6949 - accuracy: 0.95 - ETA: 1s - loss: 0.6942 - accuracy: 0.95 - ETA: 0s - loss: 0.6938 - accuracy: 0.95 - 74s 2s/step - loss: 0.6934 - accuracy: 0.9567 - val_loss: 1.3025 - val_accuracy: 0.7618
# Epoch 5/5
# 32/32 [==============================] - ETA: 42s - loss: 0.4291 - accuracy: 1.000 - ETA: 28s - loss: 0.3988 - accuracy: 1.000 - ETA: 27s - loss: 0.3903 - accuracy: 0.996 - ETA: 25s - loss: 0.3937 - accuracy: 0.995 - ETA: 24s - loss: 0.4064 - accuracy: 0.992 - ETA: 22s - loss: 0.4133 - accuracy: 0.991 - ETA: 22s - loss: 0.4195 - accuracy: 0.989 - ETA: 21s - loss: 0.4248 - accuracy: 0.989 - ETA: 20s - loss: 0.4279 - accuracy: 0.988 - ETA: 19s - loss: 0.4296 - accuracy: 0.988 - ETA: 18s - loss: 0.4324 - accuracy: 0.988 - ETA: 17s - loss: 0.4347 - accuracy: 0.987 - ETA: 16s - loss: 0.4361 - accuracy: 0.987 - ETA: 15s - loss: 0.4370 - accuracy: 0.987 - ETA: 15s - loss: 0.4375 - accuracy: 0.987 - ETA: 14s - loss: 0.4384 - accuracy: 0.987 - ETA: 13s - loss: 0.4391 - accuracy: 0.987 - ETA: 13s - loss: 0.4398 - accuracy: 0.986 - ETA: 12s - loss: 0.4403 - accuracy: 0.986 - ETA: 11s - loss: 0.4412 - accuracy: 0.986 - ETA: 10s - loss: 0.4418 - accuracy: 0.986 - ETA: 9s - loss: 0.4420 - accuracy: 0.986 - ETA: 8s - loss: 0.4423 - accuracy: 0.98 - ETA: 7s - loss: 0.4423 - accuracy: 0.98 - ETA: 6s - loss: 0.4426 - accuracy: 0.98 - ETA: 5s - loss: 0.4429 - accuracy: 0.98 - ETA: 4s - loss: 0.4433 - accuracy: 0.98 - ETA: 3s - loss: 0.4436 - accuracy: 0.98 - ETA: 2s - loss: 0.4439 - accuracy: 0.98 - ETA: 1s - loss: 0.4440 - accuracy: 0.98 - ETA: 0s - loss: 0.4441 - accuracy: 0.98 - ETA: 0s - loss: 0.4443 - accuracy: 0.98 - 58s 2s/step - loss: 0.4444 - accuracy: 0.9862 - val_loss: 1.1567 - val_accuracy: 0.7824

# %%
# early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# history = model.fit(training_batches,
#                     epochs = 100,
#                     validation_data=validation_batches,
#                     callbacks=[early_stopping])

# %%
# # Check that history.history is a dictionary
# print('history.history has type:', type(history.history))

# # Print the keys of the history.history dictionary
# print('\nThe keys of history.history are:', list(history.history.keys()))

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(EPOCHS)

plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Testing your Network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Print the loss and accuracy values achieved on the entire test set.
loss, accuracy = model.evaluate(testing_batches)

print('\nLoss on the TEST Set: {:,.3f}'.format(loss))
print('Accuracy on the TEST Set: {:.3%}'.format(accuracy))
# Out:
# 186/193 [===========================>..] - ETA: 3:23 - loss: 1.3868 - accuracy: 0.75 - ETA: 2:35 - loss: 1.2950 - accuracy: 0.76 - ETA: 2:36 - loss: 1.2275 - accuracy: 0.79 - ETA: 2:45 - loss: 1.2519 - accuracy: 0.75 - ETA: 2:47 - loss: 1.2899 - accuracy: 0.75 - ETA: 2:46 - loss: 1.3198 - accuracy: 0.75 - ETA: 2:45 - loss: 1.3111 - accuracy: 0.75 - ETA: 2:43 - loss: 1.3128 - accuracy: 0.76 - ETA: 2:41 - loss: 1.3151 - accuracy: 0.75 - ETA: 2:41 - loss: 1.3188 - accuracy: 0.75 - ETA: 2:39 - loss: 1.3254 - accuracy: 0.75 - ETA: 2:38 - loss: 1.3431 - accuracy: 0.74 - ETA: 2:37 - loss: 1.3748 - accuracy: 0.73 - ETA: 2:36 - loss: 1.3640 - accuracy: 0.73 - ETA: 2:35 - loss: 1.3488 - accuracy: 0.73 - ETA: 2:34 - loss: 1.3396 - accuracy: 0.73 - ETA: 2:33 - loss: 1.3369 - accuracy: 0.73 - ETA: 2:32 - loss: 1.3199 - accuracy: 0.73 - ETA: 2:30 - loss: 1.3112 - accuracy: 0.74 - ETA: 2:29 - loss: 1.3101 - accuracy: 0.74 - ETA: 2:29 - loss: 1.3219 - accuracy: 0.73 - ETA: 2:28 - loss: 1.3332 - accuracy: 0.73 - ETA: 2:28 - loss: 1.3270 - accuracy: 0.73 - ETA: 2:27 - loss: 1.3268 - accuracy: 0.73 - ETA: 2:26 - loss: 1.3332 - accuracy: 0.73 - ETA: 2:25 - loss: 1.3233 - accuracy: 0.73 - ETA: 2:24 - loss: 1.3370 - accuracy: 0.73 - ETA: 2:24 - loss: 1.3367 - accuracy: 0.73 - ETA: 2:22 - loss: 1.3353 - accuracy: 0.72 - ETA: 2:21 - loss: 1.3379 - accuracy: 0.72 - ETA: 2:21 - loss: 1.3324 - accuracy: 0.72 - ETA: 2:19 - loss: 1.3263 - accuracy: 0.72 - ETA: 2:19 - loss: 1.3185 - accuracy: 0.73 - ETA: 2:18 - loss: 1.3087 - accuracy: 0.73 - ETA: 2:17 - loss: 1.3063 - accuracy: 0.73 - ETA: 2:16 - loss: 1.3051 - accuracy: 0.73 - ETA: 2:15 - loss: 1.3179 - accuracy: 0.72 - ETA: 2:14 - loss: 1.3157 - accuracy: 0.72 - ETA: 2:13 - loss: 1.3115 - accuracy: 0.72 - ETA: 2:12 - loss: 1.3236 - accuracy: 0.72 - ETA: 2:12 - loss: 1.3210 - accuracy: 0.72 - ETA: 2:11 - loss: 1.3140 - accuracy: 0.72 - ETA: 2:11 - loss: 1.3133 - accuracy: 0.72 - ETA: 2:11 - loss: 1.3036 - accuracy: 0.72 - ETA: 2:10 - loss: 1.2988 - accuracy: 0.72 - ETA: 2:09 - loss: 1.2946 - accuracy: 0.72 - ETA: 2:08 - loss: 1.2968 - accuracy: 0.72 - ETA: 2:07 - loss: 1.2996 - accuracy: 0.72 - ETA: 2:06 - loss: 1.2993 - accuracy: 0.73 - ETA: 2:05 - loss: 1.3031 - accuracy: 0.73 - ETA: 2:05 - loss: 1.3000 - accuracy: 0.73 - ETA: 2:04 - loss: 1.3055 - accuracy: 0.73 - ETA: 2:03 - loss: 1.3096 - accuracy: 0.73 - ETA: 2:03 - loss: 1.3131 - accuracy: 0.72 - ETA: 2:02 - loss: 1.3091 - accuracy: 0.73 - ETA: 2:02 - loss: 1.3082 - accuracy: 0.73 - ETA: 2:02 - loss: 1.3061 - accuracy: 0.73 - ETA: 2:01 - loss: 1.3034 - accuracy: 0.73 - ETA: 2:00 - loss: 1.3001 - accuracy: 0.73 - ETA: 2:00 - loss: 1.2980 - accuracy: 0.73 - ETA: 1:59 - loss: 1.2998 - accuracy: 0.73 - ETA: 1:58 - loss: 1.2960 - accuracy: 0.73 - ETA: 1:57 - loss: 1.2950 - accuracy: 0.73 - ETA: 1:56 - loss: 1.2930 - accuracy: 0.73 - ETA: 1:55 - loss: 1.2951 - accuracy: 0.73 - ETA: 1:54 - loss: 1.2905 - accuracy: 0.73 - ETA: 1:53 - loss: 1.2857 - accuracy: 0.73 - ETA: 1:52 - loss: 1.2876 - accuracy: 0.73 - ETA: 1:51 - loss: 1.2890 - accuracy: 0.73 - ETA: 1:50 - loss: 1.2867 - accuracy: 0.73 - ETA: 1:49 - loss: 1.2873 - accuracy: 0.73 - ETA: 1:48 - loss: 1.2838 - accuracy: 0.74 - ETA: 1:47 - loss: 1.2829 - accuracy: 0.74 - ETA: 1:46 - loss: 1.2909 - accuracy: 0.73 - ETA: 1:45 - loss: 1.2896 - accuracy: 0.73 - ETA: 1:44 - loss: 1.2856 - accuracy: 0.73 - ETA: 1:44 - loss: 1.2878 - accuracy: 0.73 - ETA: 1:43 - loss: 1.2912 - accuracy: 0.73 - ETA: 1:43 - loss: 1.2863 - accuracy: 0.74 - ETA: 1:42 - loss: 1.2853 - accuracy: 0.74 - ETA: 1:42 - loss: 1.2828 - accuracy: 0.74 - ETA: 1:41 - loss: 1.2846 - accuracy: 0.74 - ETA: 1:40 - loss: 1.2899 - accuracy: 0.74 - ETA: 1:39 - loss: 1.2909 - accuracy: 0.74 - ETA: 1:39 - loss: 1.2904 - accuracy: 0.74 - ETA: 1:38 - loss: 1.2870 - accuracy: 0.74 - ETA: 1:37 - loss: 1.2883 - accuracy: 0.74 - ETA: 1:36 - loss: 1.2860 - accuracy: 0.74 - ETA: 1:35 - loss: 1.2825 - accuracy: 0.74 - ETA: 1:34 - loss: 1.2783 - accuracy: 0.74 ...
# 193/193 [==============================] - ETA: 5s - loss: 1.2826 - accuracy: 0.74 - ETA: 4s - loss: 1.2822 - accuracy: 0.74 - ETA: 3s - loss: 1.2840 - accuracy: 0.74 - ETA: 2s - loss: 1.2840 - accuracy: 0.74 - ETA: 1s - loss: 1.2829 - accuracy: 0.74 - ETA: 0s - loss: 1.2836 - accuracy: 0.74 - ETA: 0s - loss: 1.2830 - accuracy: 0.74 - 171s 883ms/step - loss: 1.2830 - accuracy: 0.7411
#
# Loss on the TEST Set: 1.283
# Accuracy on the TEST Set: 74.110%

# %% [markdown]
# ## Save the Model
#
# Now that your network is trained, save the model so you can load it later for making inference. In the cell below save your model as a Keras model (*i.e.* save it as an HDF5 file).

# %%
# TODO: Save your trained model as a Keras model.
import time

t = time.time()
#savedModel_directory ='./{}.h5'.format(t)
savedModel_directory = './mymodel.h5'
tf.saved_model.save(model, savedModel_directory)

# %%
print(savedModel_directory)
# Out:
# ./mymodel.h5

# %% [markdown]
# ## Load the Keras Model
#
# Load the Keras model you saved above.

# %%
# TODO: Load the Keras model
reloaded_SavedModel = tf.saved_model.load(savedModel_directory)

# %% [markdown]
# # Inference for Classification
#
# Now you'll write a function that uses your trained network for inference. Write a function called `predict` that takes an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# The `predict` function will also need to handle pre-processing the input image such that it can be used by your model. We recommend you write a separate function called `process_image` that performs the pre-processing. You can then call the `process_image` function from the `predict` function.
#
# ### Image Pre-processing
#
# The `process_image` function should take in an image (in the form of a NumPy array) and return an image in the form of a NumPy array with shape `(224, 224, 3)`.
#
# First, you should convert your image into a TensorFlow Tensor and then resize it to the appropriate size using `tf.image.resize`.
#
# Second, the pixel values of the input images are typically encoded as integers in the range 0-255, but the model expects the pixel values to be floats in the range 0-1. Therefore, you'll also need to normalize the pixel values.
#
# Finally, convert your image back to a NumPy array using the `.numpy()` method.

# %%
# TODO: Create the process_image function
def process_image(image):
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, (224, 224))
    image /= 255
    image = image.numpy()
    return image

# %% [markdown]
# To check your `process_image` function we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# The code below loads one of the above images using `PIL` and plots the original image alongside the image produced by your `process_image` function. If your `process_image` function works, the plotted image should be the correct size.

# %%
from PIL import Image

image_path = 'C:\\Users\\user\\Downloads\\hard-leaved_pocket_orchid.jpg'
im = Image.open(image_path)
test_image = np.asarray(im)

processed_test_image = process_image(test_image)

fig, (ax1, ax2) = plt.subplots(figsize=(10,10), ncols=2)
ax1.imshow(test_image)
ax1.set_title('Original Image')
ax2.imshow(processed_test_image)
ax2.set_title('Processed Image')
plt.tight_layout()
plt.show()

# %%
#model.predict(processed_test_image)
print(processed_test_image.shape)
# Out:
# (224, 224, 3)

# %% [markdown]
# Once you can get images in the correct format, it's time to write the `predict` function for making inference with your model.
#
# ### Inference
#
# Remember, the `predict` function should take an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# **Note:** The image returned by the `process_image` function is a NumPy array with shape `(224, 224, 3)` but the model expects the input images to be of shape `(1, 224, 224, 3)`. This extra dimension represents the batch size. We suggest you use the `np.expand_dims()` function to add the extra dimension.

# %%
# TODO: Create the predict function
def predict(image_path, model, top_k):
    im = Image.open(image_path)
    test_image = np.asarray(im)
    processed_test_image = process_image(test_image)
    processed_test_image = np.expand_dims(processed_test_image, axis=0)
    #print(processed_test_image.shape)
    probs = model.predict(processed_test_image)
    probs = probs[0].tolist()
    p,index = tf.math.top_k(probs, k=top_k)
    probs = p.numpy().tolist()
    classes = index.numpy().tolist()           
    return probs, classes

# %%
# Test model
image_path = 'C:\\Users\\user\\Downloads\\hard-leaved_pocket_orchid.jpg'
probs, classes = predict(image_path, model, 5)
class_names_pred = []
for i in range(5):
    class_names_pred.append(class_names[str(classes[i]+1)])
    print(class_names_pred[i], ':', probs[i])
# Out:
# hard-leaved pocket orchid : 0.9682775735855103
# bearded iris : 0.005148700438439846
# tiger lily : 0.003848558757454157
# mallow : 0.0030392734333872795
# king protea : 0.002045574365183711

# %%
# plot results
def plot_results(image_path, probs, classes):
    first_image = Image.open(image_path)
    first_label = class_names[str(classes[1])]
    
    class_names_pred = []
    for i in range(5):
        class_names_pred.append(class_names[str(classes[i]+1)])

    fig, (ax1, ax2) = plt.subplots(figsize=(9,9), ncols=2)
    ax1.imshow(first_image, cmap = plt.cm.binary)
    ax1.axis('off')
    ax1.set_title(class_names_pred[0])
    ax2.barh(np.arange(5), probs)
    ax2.set_aspect(0.1)
    ax2.set_yticks(np.arange(5))
    ax2.set_yticklabels(class_names_pred, size='small');
    ax2.set_title('Class Probability')
    ax2.set_xlim(0, 1.1)
    plt.tight_layout()

# %%
plot_results(image_path, probs, classes)

# %% [markdown]
# # Sanity Check
#
# It's always good to check the predictions made by your model to make sure they are correct. To check your predictions we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# In the cell below use `matplotlib` to plot the input image alongside the probabilities for the top 5 classes predicted by your model. Plot the probabilities as a bar graph. The plot should look like this:
#
# <img src='assets/inference_example.png' width=600px>
#
# You can convert from the class integer labels to actual flower names using `class_names`.

# %%
# TODO: Plot the input image along with the top 5 classes
path_list = ['C:\\Users\\user\\Downloads\\cautleya_spicata.jpg',
            'C:\\Users\\user\\Downloads\\hard-leaved_pocket_orchid.jpg',
            'C:\\Users\\user\\Downloads\\orange_dahlia.jpg',
            'C:\\Users\\user\\Downloads\\wild_pansy.jpg']

for j in path_list:
    print('\n', j)
    probs, classes = predict(j, model, 5)
    plot_results(j, probs, classes)
#     for i in range(5):
#         print(class_names[str(classes[i]+1)], ':', probs[i])
# Out:
#  C:\Users\user\Downloads\cautleya_spicata.jpg
#
#  C:\Users\user\Downloads\hard-leaved_pocket_orchid.jpg
#
#  C:\Users\user\Downloads\orange_dahlia.jpg
#
#  C:\Users\user\Downloads\wild_pansy.jpg
